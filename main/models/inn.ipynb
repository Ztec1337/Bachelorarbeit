# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from sklearn.datasets import make_moons
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_probability as tfp
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
data = make_moons(3000, noise=0.05)[0].astype("float32")
norm = layers.Normalization()
norm.adapt(data)
normalized_data = norm(data)

# %%
# Creating a custom layer with keras API.
output_dim = 256
reg = 0.01


def Coupling(input_shape):
    input = keras.layers.Input(shape=input_shape)

    t_layer_1 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(input)
    t_layer_2 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_1)
    t_layer_3 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_2)
    t_layer_4 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_3)
    t_layer_5 = keras.layers.Dense(
        input_shape, activation="linear", kernel_regularizer=regularizers.l2(reg)
    )(t_layer_4)

    s_layer_1 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(input)
    s_layer_2 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_1)
    s_layer_3 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_2)
    s_layer_4 = keras.layers.Dense(
        output_dim, activation="relu", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_3)
    s_layer_5 = keras.layers.Dense(
        input_shape, activation="tanh", kernel_regularizer=regularizers.l2(reg)
    )(s_layer_4)

    return keras.Model(inputs=input, outputs=[s_layer_5, t_layer_5])

# %%
class RealNVP(keras.Model):
    def __init__(self, num_coupling_layers):
        super(RealNVP, self).__init__()

        self.num_coupling_layers = num_coupling_layers

        # Distribution of the latent space.
        self.distribution = tfp.distributions.MultivariateNormalDiag(
            loc=[0.0, 0.0], scale_diag=[1.0, 1.0]
        )
        self.masks = np.array(
            [[0, 1], [1, 0]] * (num_coupling_layers // 2), dtype="float32"
        )
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.layers_list = [Coupling(2) for i in range(num_coupling_layers)]

    @property
    def metrics(self):
        """List of the model's metrics.

        We make sure the loss tracker is listed as part of `model.metrics`
        so that `fit()` and `evaluate()` are able to `reset()` the loss tracker
        at the start of each epoch and at the start of an `evaluate()` call.
        """
        return [self.loss_tracker]

    def call(self, x, training=True):
        log_det_inv = 0
        direction = 1
        if training:
            direction = -1
        for i in range(self.num_coupling_layers)[::direction]:
            x_masked = x * self.masks[i]
            reversed_mask = 1 - self.masks[i]
            s, t = self.layers_list[i](x_masked)
            s *= reversed_mask
            t *= reversed_mask
            gate = (direction - 1) / 2
            x = (
                reversed_mask
                * (x * tf.exp(direction * s) + direction * t * tf.exp(gate * s))
                + x_masked
            )
            log_det_inv += gate * tf.reduce_sum(s, [1])

        return x, log_det_inv

    # Log likelihood of the normal distribution plus the log determinant of the jacobian.

    def log_loss(self, x):
        y, logdet = self(x)
        log_likelihood = self.distribution.log_prob(y) + logdet
        return -tf.reduce_mean(log_likelihood)

    def train_step(self, data):
        with tf.GradientTape() as tape:

            loss = self.log_loss(data)

        g = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(g, self.trainable_variables))
        self.loss_tracker.update_state(loss)

        return {"loss": self.loss_tracker.result()}

    def test_step(self, data):
        loss = self.log_loss(data)
        self.loss_tracker.update_state(loss)

        return {"loss": self.loss_tracker.result()}

# %%
model = RealNVP(num_coupling_layers=6)

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001))

history = model.fit(
    normalized_data, batch_size=256, epochs=100, verbose=2, validation_split=0.2
)
# Out:
# Epoch 1/100
# 10/10 - 4s - loss: 2.7221 - val_loss: 2.6068 - 4s/epoch - 421ms/step
# Epoch 2/100
# 10/10 - 0s - loss: 2.6065 - val_loss: 2.5578 - 266ms/epoch - 27ms/step
# Epoch 3/100
# 10/10 - 0s - loss: 2.5520 - val_loss: 2.5160 - 266ms/epoch - 27ms/step
# Epoch 4/100
# 10/10 - 0s - loss: 2.5031 - val_loss: 2.4884 - 266ms/epoch - 27ms/step
# Epoch 5/100
# 10/10 - 0s - loss: 2.4649 - val_loss: 2.4625 - 250ms/epoch - 25ms/step
# Epoch 6/100
# 10/10 - 0s - loss: 2.4379 - val_loss: 2.4380 - 250ms/epoch - 25ms/step
# Epoch 7/100
# 10/10 - 0s - loss: 2.4077 - val_loss: 2.4178 - 250ms/epoch - 25ms/step
# Epoch 8/100
# 10/10 - 0s - loss: 2.3779 - val_loss: 2.3902 - 330ms/epoch - 33ms/step
# Epoch 9/100
# 10/10 - 0s - loss: 2.3597 - val_loss: 2.3645 - 281ms/epoch - 28ms/step
# Epoch 10/100
# 10/10 - 0s - loss: 2.3411 - val_loss: 2.3435 - 328ms/epoch - 33ms/step
# Epoch 11/100
# 10/10 - 0s - loss: 2.3212 - val_loss: 2.3164 - 328ms/epoch - 33ms/step
# Epoch 12/100
# 10/10 - 0s - loss: 2.2843 - val_loss: 2.2809 - 266ms/epoch - 27ms/step
# Epoch 13/100
# 10/10 - 0s - loss: 2.2519 - val_loss: 2.2534 - 266ms/epoch - 27ms/step
# Epoch 14/100
# 10/10 - 0s - loss: 2.2145 - val_loss: 2.2070 - 226ms/epoch - 23ms/step
# Epoch 15/100
# 10/10 - 0s - loss: 2.1742 - val_loss: 2.1922 - 250ms/epoch - 25ms/step
# Epoch 16/100
# 10/10 - 0s - loss: 2.1594 - val_loss: 2.1517 - 234ms/epoch - 23ms/step
# Epoch 17/100
# 10/10 - 0s - loss: 2.1313 - val_loss: 2.1355 - 234ms/epoch - 23ms/step
# Epoch 18/100
# 10/10 - 0s - loss: 2.1038 - val_loss: 2.1148 - 240ms/epoch - 24ms/step
# Epoch 19/100
# 10/10 - 0s - loss: 2.0917 - val_loss: 2.0913 - 297ms/epoch - 30ms/step
# Epoch 20/100
# 10/10 - 0s - loss: 2.0676 - val_loss: 2.0716 - 266ms/epoch - 27ms/step
# Epoch 21/100
# 10/10 - 0s - loss: 2.0409 - val_loss: 2.0315 - 266ms/epoch - 27ms/step
# Epoch 22/100
# 10/10 - 0s - loss: 2.0096 - val_loss: 2.0027 - 222ms/epoch - 22ms/step
# Epoch 23/100
# 10/10 - 0s - loss: 1.9652 - val_loss: 1.9436 - 250ms/epoch - 25ms/step
# Epoch 24/100
# 10/10 - 0s - loss: 1.9452 - val_loss: 1.9242 - 379ms/epoch - 38ms/step
# Epoch 25/100
# 10/10 - 0s - loss: 1.8627 - val_loss: 1.8511 - 437ms/epoch - 44ms/step
# Epoch 26/100
# 10/10 - 0s - loss: 1.8070 - val_loss: 1.8151 - 234ms/epoch - 23ms/step
# Epoch 27/100
# 10/10 - 0s - loss: 1.7625 - val_loss: 1.7206 - 235ms/epoch - 23ms/step
# Epoch 28/100
# 10/10 - 1s - loss: 1.6916 - val_loss: 1.6763 - 531ms/epoch - 53ms/step
# Epoch 29/100
# 10/10 - 0s - loss: 1.6594 - val_loss: 1.6945 - 250ms/epoch - 25ms/step
# Epoch 30/100
# 10/10 - 0s - loss: 1.6876 - val_loss: 1.6865 - 234ms/epoch - 23ms/step
# Epoch 31/100
# 10/10 - 0s - loss: 1.6239 - val_loss: 1.6155 - 297ms/epoch - 30ms/step
# Epoch 32/100
# 10/10 - 0s - loss: 1.5891 - val_loss: 1.6154 - 380ms/epoch - 38ms/step
# Epoch 33/100
# 10/10 - 0s - loss: 1.6017 - val_loss: 1.5825 - 250ms/epoch - 25ms/step
# Epoch 34/100
# 10/10 - 0s - loss: 1.6027 - val_loss: 1.5765 - 312ms/epoch - 31ms/step
# Epoch 35/100
# 10/10 - 0s - loss: 1.5705 - val_loss: 1.6024 - 298ms/epoch - 30ms/step
# Epoch 36/100
# 10/10 - 0s - loss: 1.5664 - val_loss: 1.5680 - 281ms/epoch - 28ms/step
# Epoch 37/100
# 10/10 - 0s - loss: 1.5965 - val_loss: 1.5672 - 234ms/epoch - 23ms/step
# Epoch 38/100
# 10/10 - 0s - loss: 1.5758 - val_loss: 1.5527 - 328ms/epoch - 33ms/step
# Epoch 39/100
# 10/10 - 0s - loss: 1.5328 - val_loss: 1.5375 - 312ms/epoch - 31ms/step
# Epoch 40/100
# 10/10 - 0s - loss: 1.5204 - val_loss: 1.5261 - 245ms/epoch - 25ms/step
# Epoch 41/100
# 10/10 - 0s - loss: 1.5187 - val_loss: 1.5120 - 236ms/epoch - 24ms/step
# Epoch 42/100
# 10/10 - 0s - loss: 1.5272 - val_loss: 1.5727 - 240ms/epoch - 24ms/step
# Epoch 43/100
# 10/10 - 0s - loss: 1.5534 - val_loss: 1.5505 - 219ms/epoch - 22ms/step
# Epoch 44/100
# 10/10 - 0s - loss: 1.5413 - val_loss: 1.4930 - 236ms/epoch - 24ms/step
# Epoch 45/100
# 10/10 - 0s - loss: 1.5032 - val_loss: 1.5520 - 219ms/epoch - 22ms/step
# Epoch 46/100
# 10/10 - 0s - loss: 1.5185 - val_loss: 1.5327 - 234ms/epoch - 23ms/step
# Epoch 47/100
# 10/10 - 0s - loss: 1.4923 - val_loss: 1.4773 - 243ms/epoch - 24ms/step
# Epoch 48/100
# 10/10 - 0s - loss: 1.4719 - val_loss: 1.4446 - 250ms/epoch - 25ms/step
# Epoch 49/100
# 10/10 - 0s - loss: 1.4661 - val_loss: 1.4823 - 246ms/epoch - 25ms/step
# Epoch 50/100
# 10/10 - 1s - loss: 1.4747 - val_loss: 1.4904 - 501ms/epoch - 50ms/step
# Epoch 51/100
# 10/10 - 0s - loss: 1.4556 - val_loss: 1.4422 - 297ms/epoch - 30ms/step
# Epoch 52/100
# 10/10 - 0s - loss: 1.4419 - val_loss: 1.4196 - 281ms/epoch - 28ms/step
# Epoch 53/100
# 10/10 - 0s - loss: 1.4161 - val_loss: 1.4704 - 266ms/epoch - 27ms/step
# Epoch 54/100
# 10/10 - 0s - loss: 1.4367 - val_loss: 1.4214 - 251ms/epoch - 25ms/step
# Epoch 55/100
# 10/10 - 0s - loss: 1.4075 - val_loss: 1.4560 - 250ms/epoch - 25ms/step
# Epoch 56/100
# 10/10 - 0s - loss: 1.4145 - val_loss: 1.4373 - 289ms/epoch - 29ms/step
# Epoch 57/100
# 10/10 - 0s - loss: 1.4073 - val_loss: 1.4662 - 219ms/epoch - 22ms/step
# Epoch 58/100
# 10/10 - 0s - loss: 1.4310 - val_loss: 1.4603 - 266ms/epoch - 27ms/step
# Epoch 59/100
# 10/10 - 0s - loss: 1.4556 - val_loss: 1.4658 - 328ms/epoch - 33ms/step
# Epoch 60/100
# 10/10 - 0s - loss: 1.4233 - val_loss: 1.5282 - 438ms/epoch - 44ms/step
# Epoch 61/100
# 10/10 - 1s - loss: 1.3968 - val_loss: 1.3921 - 578ms/epoch - 58ms/step
# Epoch 62/100
# 10/10 - 1s - loss: 1.3752 - val_loss: 1.4289 - 516ms/epoch - 52ms/step
# Epoch 63/100
# 10/10 - 0s - loss: 1.4730 - val_loss: 1.4634 - 328ms/epoch - 33ms/step
# Epoch 64/100
# 10/10 - 0s - loss: 1.4492 - val_loss: 1.5156 - 312ms/epoch - 31ms/step
# Epoch 65/100
# 10/10 - 0s - loss: 1.4170 - val_loss: 1.4209 - 297ms/epoch - 30ms/step
# Epoch 66/100
# 10/10 - 0s - loss: 1.3596 - val_loss: 1.4121 - 281ms/epoch - 28ms/step
# Epoch 67/100
# 10/10 - 0s - loss: 1.3627 - val_loss: 1.4004 - 297ms/epoch - 30ms/step
# Epoch 68/100
# 10/10 - 0s - loss: 1.3129 - val_loss: 1.4114 - 297ms/epoch - 30ms/step
# Epoch 69/100
# 10/10 - 0s - loss: 1.3607 - val_loss: 1.4052 - 298ms/epoch - 30ms/step
# Epoch 70/100
# 10/10 - 0s - loss: 1.3389 - val_loss: 1.4122 - 297ms/epoch - 30ms/step
# Epoch 71/100
# 10/10 - 0s - loss: 1.3496 - val_loss: 1.4266 - 281ms/epoch - 28ms/step
# Epoch 72/100
# 10/10 - 0s - loss: 1.3288 - val_loss: 1.3838 - 281ms/epoch - 28ms/step
# Epoch 73/100
# 10/10 - 0s - loss: 1.3273 - val_loss: 1.3525 - 297ms/epoch - 30ms/step
# Epoch 74/100
# 10/10 - 0s - loss: 1.3513 - val_loss: 1.3419 - 304ms/epoch - 30ms/step
# Epoch 75/100
# 10/10 - 0s - loss: 1.3350 - val_loss: 1.3703 - 305ms/epoch - 31ms/step
# Epoch 76/100
# 10/10 - 0s - loss: 1.3312 - val_loss: 1.3102 - 293ms/epoch - 29ms/step
# Epoch 77/100
# 10/10 - 0s - loss: 1.2835 - val_loss: 1.3228 - 294ms/epoch - 29ms/step
# Epoch 78/100
# 10/10 - 0s - loss: 1.2801 - val_loss: 1.3707 - 291ms/epoch - 29ms/step
# Epoch 79/100
# 10/10 - 0s - loss: 1.2863 - val_loss: 1.3093 - 291ms/epoch - 29ms/step
# Epoch 80/100
# 10/10 - 0s - loss: 1.2676 - val_loss: 1.2886 - 293ms/epoch - 29ms/step
# Epoch 81/100
# 10/10 - 0s - loss: 1.2926 - val_loss: 1.3118 - 295ms/epoch - 30ms/step
# Epoch 82/100
# 10/10 - 0s - loss: 1.3008 - val_loss: 1.3183 - 292ms/epoch - 29ms/step
# Epoch 83/100
# 10/10 - 0s - loss: 1.2669 - val_loss: 1.2993 - 293ms/epoch - 29ms/step
# Epoch 84/100
# 10/10 - 0s - loss: 1.2646 - val_loss: 1.2842 - 293ms/epoch - 29ms/step
# Epoch 85/100
# 10/10 - 0s - loss: 1.2651 - val_loss: 1.2650 - 291ms/epoch - 29ms/step
# Epoch 86/100
# 10/10 - 0s - loss: 1.2482 - val_loss: 1.2512 - 291ms/epoch - 29ms/step
# Epoch 87/100
# 10/10 - 0s - loss: 1.2575 - val_loss: 1.2773 - 295ms/epoch - 30ms/step
# Epoch 88/100
# 10/10 - 0s - loss: 1.2436 - val_loss: 1.2617 - 300ms/epoch - 30ms/step
# Epoch 89/100
# 10/10 - 0s - loss: 1.2437 - val_loss: 1.2640 - 307ms/epoch - 31ms/step
# Epoch 90/100
# 10/10 - 0s - loss: 1.2837 - val_loss: 1.3179 - 302ms/epoch - 30ms/step
# Epoch 91/100
# 10/10 - 0s - loss: 1.2880 - val_loss: 1.2942 - 309ms/epoch - 31ms/step
# Epoch 92/100
# 10/10 - 0s - loss: 1.2370 - val_loss: 1.2395 - 305ms/epoch - 31ms/step
# Epoch 93/100
# 10/10 - 0s - loss: 1.2352 - val_loss: 1.2511 - 336ms/epoch - 34ms/step
# Epoch 94/100
# 10/10 - 0s - loss: 1.2289 - val_loss: 1.2526 - 314ms/epoch - 31ms/step
# Epoch 95/100
# 10/10 - 0s - loss: 1.2732 - val_loss: 1.2663 - 313ms/epoch - 31ms/step
# Epoch 96/100
# 10/10 - 0s - loss: 1.2554 - val_loss: 1.2507 - 324ms/epoch - 32ms/step
# Epoch 97/100
# 10/10 - 0s - loss: 1.2462 - val_loss: 1.2815 - 436ms/epoch - 44ms/step
# Epoch 98/100
# 10/10 - 0s - loss: 1.2308 - val_loss: 1.2754 - 440ms/epoch - 44ms/step
# Epoch 99/100
# 10/10 - 1s - loss: 1.2275 - val_loss: 1.2358 - 513ms/epoch - 51ms/step
# Epoch 100/100
# 10/10 - 1s - loss: 1.2478 - val_loss: 1.2727 - 528ms/epoch - 53ms/step

# %%
plt.figure(figsize=(15, 10))
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.legend(["train", "validation"], loc="upper right")
plt.ylabel("loss")
plt.xlabel("epoch")

# From data to latent space.
z, _ = model(normalized_data)

# From latent space to data.
samples = model.distribution.sample(3000)
x, _ = model.predict(samples)

f, axes = plt.subplots(2, 2)
f.set_size_inches(20, 15)

axes[0, 0].scatter(normalized_data[:, 0], normalized_data[:, 1], color="r")
axes[0, 0].set(title="Inference data space X", xlabel="x", ylabel="y")
axes[0, 1].scatter(z[:, 0], z[:, 1], color="r")
axes[0, 1].set(title="Inference latent space Z", xlabel="x", ylabel="y")
axes[0, 1].set_xlim([-3.5, 4])
axes[0, 1].set_ylim([-4, 4])
axes[1, 0].scatter(samples[:, 0], samples[:, 1], color="g")
axes[1, 0].set(title="Generated latent space Z", xlabel="x", ylabel="y")
axes[1, 1].scatter(x[:, 0], x[:, 1], color="g")
axes[1, 1].set(title="Generated data space X", label="x", ylabel="y")
axes[1, 1].set_xlim([-2, 2])
axes[1, 1].set_ylim([-2, 2])
# Out:
# 94/94 [==============================] - 1s 4ms/step
# (-2.0, 2.0)
